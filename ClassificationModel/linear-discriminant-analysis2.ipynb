# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder, PolynomialFeatures
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Load dataset
df = pd.read_csv("../Data/breast-cancer-dataset-augmented.csv")

print("Preview dataset:")
print(df.head())
print("\nInfo:")
print(df.info())

# 2. Pisahkan fitur (X) dan label (y)
X = df[["SDNN", "rMSSD", "pNN50"]]  # Fitur asli
y = df["Class"]                     # Label

# Jika target berupa string (misal: 'M' / 'B'), ubah ke angka
if y.dtype == 'object':
    le = LabelEncoder()
    y = le.fit_transform(y)
    print("Mapping kelas:", dict(zip(le.classes_, le.transform(le.classes_))))

# 3. Tambah polynomial features
poly = PolynomialFeatures(degree=2, include_bias=False)
X_poly = poly.fit_transform(X)

print("\nJumlah fitur sebelum:", X.shape[1])
print("Jumlah fitur setelah polynomial:", X_poly.shape[1])

# 4. Split data train & test
X_train, X_test, y_train, y_test = train_test_split(
    X_poly, y, test_size=0.2, random_state=42, stratify=y
)

# 5. Normalisasi fitur
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# 6. GridSearch untuk tuning LDA
param_grid = {
    "solver": ["svd", "lsqr", "eigen"],
    "shrinkage": [None, "auto"]  # shrinkage hanya relevan untuk lsqr/eigen
}

grid = GridSearchCV(
    LinearDiscriminantAnalysis(),
    param_grid,
    cv=5,
    scoring="accuracy",
    n_jobs=-1
)

grid.fit(X_train, y_train)

print("\nBest Params:", grid.best_params_)
print("Best CV Score (Train):", grid.best_score_)

# Gunakan model terbaik
best_lda = grid.best_estimator_
y_pred = best_lda.predict(X_test)

# 7. Evaluasi
print("\nAkurasi (Test):", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
plt.figure(figsize=(6,4))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues")
plt.xlabel("Prediksi")
plt.ylabel("Aktual")
plt.title("Confusion Matrix - Best LDA with Polynomial Features")
plt.show()
# Out:
# Preview dataset:
#          SDNN      rMSSD      pNN50  Class
# 0   53.998699  18.990753   1.005517      1
# 1  157.984773  36.002740  14.999960      1
# 2  128.998804  24.003266   4.005418      1
# 3   61.993824  13.005822  -0.005091      1
# 4  101.018840  17.987722   1.008869      1
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SDNN    380 non-null    float64
#  1   rMSSD   380 non-null    float64
#  2   pNN50   380 non-null    float64
#  3   Class   380 non-null    int64
# dtypes: float64(3), int64(1)
# memory usage: 12.0 KB
# None
#
# Jumlah fitur sebelum: 3
# Jumlah fitur setelah polynomial: 9
#
# Best Params: {'shrinkage': None, 'solver': 'svd'}
# Best CV Score (Train): 0.6841530054644809
#
# Akurasi (Test): 0.6710526315789473
#
# Classification Report:
#                precision    recall  f1-score   support
#
# ...
